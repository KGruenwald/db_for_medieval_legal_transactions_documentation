# %%
import os
import pandas as pd
import re
from lxml import etree
from datetime import datetime

ns = {'tei': 'http://www.tei-c.org/ns/1.0', "xml": "http://www.w3.org/XML/1998/namespace"}




def readlist(pathtofile, filename):
      tree = etree.parse(pathtofile+"/"+filename)
      return tree



def readfiles(pathtofiles, listpersons):
    listpersonids = []
    notfoundlist = []
    regestlist = []
    for listperson in listpersons:
      listpersonids.append(listperson.attrib["{http://www.w3.org/XML/1998/namespace}id"])
    for filename in os.listdir(pathtofiles):
       regesttree = etree.parse(pathtofiles+"/"+filename)
       regestroot = regesttree.getroot()
       refs = regestroot.xpath('//*[@type="person"]/@ref')
       distrefs = list(set(refs))

       for distref in distrefs:
           cleanedup = distref.replace("#", "")
           if  cleanedup not in listpersonids:
                notfoundlist.append(distref)
                regestlist.append(filename)
           else:
               print("gefunden: " +distref)

    print(notfoundlist)
    personframe = pd.DataFrame()
    personframe['regest'] = regestlist
    personframe['id'] = notfoundlist

    writer = pd.ExcelWriter('../data/output/xlsx/notfoundPersons.xlsx')
    personframe.to_excel(writer, 'notfoundPersons', index=False)
    writer.save()

    personframe.to_csv("../data/output/csv/notfoundPersons.csv", sep="\t", encoding="utf-8")


personlistroot = readlist("../../data/lists", "personList.xml")

listpersons = personlistroot.findall('//tei:person', ns)

readfiles("../../regests_QGW_LV_Methodenkurs/done", listpersons)
# Out:
# gefunden: #pe__jakob_QGW_II_I_1641
# gefunden: #pe__leonhard_schaur
# gefunden: #pe__peter_bernardi_von_rosenheim
# gefunden: #pe__jakob_waldner_QGW_II_I_1641
# gefunden: #pe__martin_QGW_II_I_1641
# gefunden: #pe__bartholomaeus_wuerfel
# gefunden: #pe__niklas_von_der_schemnitz_iii
# gefunden: #pe__heinrich_bei_dem_steg_QGW_II_I_1642
# gefunden: #pe__stephan_QGW_II_I_1642
# gefunden: #pe__johann_hirnprech
# gefunden: #pe__elisabeth_QGW_II_I_1642
# gefunden: #pe__johann_fuechsel
# gefunden: #pe__jakob_guens_ii
# gefunden: #pe__elisabeth_QGW_II_I_1643
# gefunden: #pe__katharina_QGW_II_I_1643
# gefunden: #pe__arnold_von_seehausen_QGW_II_I_1644
# gefunden: #pe__niklas_von_eslarn_vii
# gefunden: #pe__dietrich_prenner
# gefunden: #pe__johann_QGW_II_I_1645
# gefunden: #pe__johann_zinkk_QGW_II_I_1645
# gefunden: #pe__elisabeth_QGW_II_I_1646
# gefunden: #pe__stephan_der_lang_QGW_II_I_1646
# gefunden: #pe__bertha_QGW_II_I_1646
# gefunden: #pe__johann_schaffer_QGW_II_I_1646
# gefunden: #pe__johann_poelzl_QGW_II_I_1646
# gefunden: #pe__laurenz_QGW_II_I_1646
# gefunden: #pe__niklas_QGW_II_I_1647
# gefunden: #pe__barbara_QGW_II_I_1488
# gefunden: #pe__rudolf_angerfelder
