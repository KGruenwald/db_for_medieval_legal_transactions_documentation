# %%
import os
import pandas as pd
import re
from lxml import etree
from datetime import datetime

ns = {'tei': 'http://www.tei-c.org/ns/1.0', "xml": "http://www.w3.org/XML/1998/namespace"}


def readlist(pathtofile, filename):
      tree = etree.parse(pathtofile+"/"+filename)
      root = tree.getroot()
      return root

def readfiles(pathtofiles, listxml):
    listoforganisations = []
    for filename in os.listdir(pathtofiles):
       regesttree = etree.parse(pathtofiles+"/"+filename)
       regestroot = regesttree.getroot()
       actualregest = regestroot.find(".//tei:idno", ns).text
       date = createdate(regestroot.find(".//tei:creation/tei:date", ns))
       organisationNodes = regestroot.findall(".//*[@type='org']")
       for rs in organisationNodes:
           organisation = createneworganisation(rs, listxml)
           organisation.append(actualregest)
           organisation.append(date)
           listoforganisations.append(organisation)

    createcoloumns(listoforganisations)    
    
def createcoloumns(listoforganisations):
    organisationsFrame = pd.DataFrame()
    reflist = []
    regesttext = []
    type =[]
    observance = []
    eventref = []
    regest = []
    regname =[]
    date =[]
    fnrole = []
    
    for org in listoforganisations:
        print(org)
        if org[0] != "": reflist.append(org[0])
        else: reflist.append(" ")
        
        if org[1] != "": regesttext.append(org[1])
        else: regesttext.append(" ")
        
        if len(org[2]) >0:
            if org[2][0] != "": type.append(org[2][0])
            else: type.append(" ")
            if org[2][1] != "": observance.append(org[2][1])
            else: observance.append(" ")
            if org[2][2] != "": regname.append(org[2][2])
            else: regname.append(" ")
            
        if len(org[3]) >0: eventref.append(org[3])
        else: eventref.append(" ")
    
        if len(org[4])>0: fnrole.append(org[4])
        else: fnrole.append(" ")
        
        if len(org[5]) >0: regest.append(org[5])
        else: regest.append(" ")

        date.append(org[6])  
          


        
    organisationsFrame['ref'] = reflist
    organisationsFrame['regest'] = regest
    organisationsFrame['Regest Text'] = regesttext 
    organisationsFrame['reg Name'] = regname
    organisationsFrame['type'] = type
    organisationsFrame['observance'] = observance
    organisationsFrame['fn role'] = fnrole
    organisationsFrame['Events ref']  = eventref
    organisationsFrame['regest date'] = date

    
    writer = pd.ExcelWriter('../data/output/xlsx/extractedAllOrganisations.xlsx')
    organisationsFrame.to_excel(writer, 'ExtractedAllOrganisations', index=False)
    writer.save()
    
    organisationsFrame.to_csv("../data/output/csv/extractedAllOrganisations.csv", sep="\t", encoding="utf-8")


def createneworganisation(rs, listxml):
        text = cleanuptextnodestostring(rs.xpath(".//text()"))
        rsrole = getrstyperole(rs)
        events = getorgevent(rs)
        ref = rs.attrib["ref"]
        org = getinformationsfromorglistxml(ref, listxml)
        return [ref, text, org, events, rsrole]

def getrstyperole(node):
    parentrs = node.find("./..[@type='fn']", ns)
    if parentrs is not None:
        return parentrs.attrib['role']
    else:
        return " "

def getorgevent(node):
    
    eventnode = getparentevent(node)
    if eventnode is not None:
        event_ref = eventnode.attrib['ref']
        return event_ref
    else: return ""


def getparentevent(node):
        actualnode = node
        parents = actualnode.xpath("ancestor::*[@type='event']")
        return parents[0]


    

def createdate(node):
    when = node.attrib['when']
    return datetime.strptime(when, '%Y%m%d').date()


def getinformationsfromorglistxml(ref, orglist):
    ref = ref.replace("#", '')
    org = orglist.find(".//tei:org[@xml:id='"+ref+"']", ns)
    name = " "
    if org is not None:
        regname = org.find(".//tei:reg",ns)
        if regname is not None:
            name = regname.text
        if "type" in org.attrib:
            type = org.attrib['type']
            if "Kloster_" in type:
               observance = org.find(".//tei:label",ns).text
               desc = org.find(".//tei:desc", ns).text
               return [type, desc, name]
            else: return [type, " ", name]
    else: return[" ", " ", " "]




def cleanuptextnodestostring(textnodes):
    cleanedlist =[]
    for textnode in textnodes:
        textstring = str(textnode)
        tokenized = textstring.split(" ")
        cleandtokens = []
        for token in tokenized:
            if len(token) >1:
                token = re.sub("\n","", token)
                cleandtokens.append(token)
        cleanedlist += cleandtokens    
    return " ".join(cleanedlist) 

personlistxml = readlist("../../data/lists", "orgList.xml")    
readfiles("../../regests_QGW_PR_Stadt_ab_1400/done", personlistxml)
# Out:
# ['#org__st_stephan', 'sand Jacob auf Unser Vraun altar', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1484', 'recipient', '1484', datetime.date(1401, 2, 17)]
# ['#org__st_stephan', 'Stephan ze Wienne', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1484', 'recipient', '1484', datetime.date(1401, 2, 17)]
# ['#org__dominikaner', 'den Predigern', ['Kloster_m', 'OP', 'Dominikaner'], '#ev__QGW_II_I_1484', 'recipient', '1484', datetime.date(1401, 2, 17)]
# ['#org__augustinereremiten', 'den Augustinern', ['Kloster_m', 'OESA', 'Augustinereremiten'], '#ev__QGW_II_I_1484', 'recipient', '1484', datetime.date(1401, 2, 17)]
# ['#org__karmeliter', 'den Weissenprüdern', ['Kloster_m', 'OCarm', 'Karmeliter-Weissenbrüder'], '#ev__QGW_II_I_1484', 'recipient', '1484', datetime.date(1401, 2, 17)]
# ['#org__st_johannes_in_der_siechenals', 'sand Johanns in der Siechen Alz/zz/z', ['Kirche_Kapelle', ' ', 'St. Johannes in der Siechenals'], '#ev__QGW_II_I_1484', 'recipient', '1484', datetime.date(1401, 2, 17)]
# ['#org__st_lazarus_siechenhaus', 'sand Marx', ['Spital_Siechenhaus', ' ', 'St. Lazarus-Siechenhaus (St.\n       Marx)'], '#ev__QGW_II_I_1484', 'recipient', '1484', datetime.date(1401, 2, 17)]
# ['#org__st_hiob_zum_klagbaum', 'dem Chlagpaum', ['Kirche_Kapelle', ' ', 'St. Hiob-zum Klagbaum'], '#ev__QGW_II_I_1484', 'recipient', '1484', datetime.date(1401, 2, 17)]
# ['#org__buergerspital', 'bürger Spital', ['Spital_Siechenhaus', ' ', 'Bürgerspital'], '#ev__QGW_II_I_1484', 'recipient', '1484', datetime.date(1401, 2, 17)]
# ['#org__st_jakob_auf_der_huelben', 'sand Jacob', ['Kloster_f', 'CanReg', 'St. Jakob-auf der Hülben'], '#ev__QGW_II_I_1484', 'recipient', '1484', datetime.date(1401, 2, 17)]
# ['#org__st_hieronymus', 'sand Hieronymus', ['Kloster_f', 'OSMM', ' '], '#ev__QGW_II_I_1484', 'recipient', '1484', datetime.date(1401, 2, 17)]
# ['#org__st_stephan', 'Todtenbuch bei S. Stephan', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1484', 'recipient', '1484', datetime.date(1401, 2, 17)]
# ['#org__st_stephan', 'achtherren hinz sand Stephan', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1484', 'recipient', '1484', datetime.date(1401, 2, 17)]
# ['#org__st_jakob_auf_der_huelben', 'S. Jakob', ['Kloster_f', 'CanReg', 'St. Jakob-auf der Hülben'], '#ev__QGW_II_I_1484', 'recipient', '1484', datetime.date(1401, 2, 17)]
# ['#org__st_peter', 'sand Peter ze Wienn', ['Kirche_Kapelle', ' ', 'St. Peter'], '#ev__QGW_II_I_1486_a', ' ', '1486', datetime.date(1401, 4, 24)]
# ['#org__st_peter', 'Messe', ['Kirche_Kapelle', ' ', 'St. Peter'], '#ev__QGW_II_I_1486_b', 'recipient', '1486', datetime.date(1401, 4, 24)]
# ['#org__antiochia_dioezese', 'Antiochia', ['Dioezese_Erzdioezese', ' ', ' '], '#ev__QGW_II_I_1487', ' ', '1487', datetime.date(1401, 4, 25)]
# ['#org__st_peter_wissegard', 'Wissehrader Kirche', ['Kirche_Kapelle', ' ', ' '], '#ev__QGW_II_I_1487', ' ', '1487', datetime.date(1401, 4, 25)]
# ['#org__nalb_pfarre', 'Pfarrkirche in Neliv, Pataviensis diocesis', ['Pfarre', ' ', ' '], '#ev__QGW_II_I_1487', ' ', '1487', datetime.date(1401, 4, 25)]
# ['#org__prag_dioezese', 'Pragensis diocesis', ['Dioezese_Erzdioezese', ' ', ' '], '#ev__QGW_II_I_1487', ' ', '1487', datetime.date(1401, 4, 25)]
# ['#org__buergerspital', 'purger Spital vor Chêrnertor ze Wienn', ['Spital_Siechenhaus', ' ', 'Bürgerspital'], '#ev__QGW_II_I_1489', ' ', '1489', datetime.date(1401, 6, 22)]
# ['#org__st_niklas_vor_dem_stubentor', 'geistleichen frown dacz sand Niclas var Stubentar ze Wienn', ['Kloster_f', 'OCist', 'St. Niklas-vor dem Stubentor'], '#ev__QGW_II_I_1490', ' ', '1490', datetime.date(1401, 7, 9)]
# ['#org__antiochia_dioezese', 'Antiochia', ['Dioezese_Erzdioezese', ' ', ' '], '#ev__QGW_II_I_1487', ' ', '1492', datetime.date(1401, 8, 10)]
# ['#org__st_peter_wissegard', 'Wissehrader Kirche', ['Kirche_Kapelle', ' ', ' '], '#ev__QGW_II_I_1487', ' ', '1492', datetime.date(1401, 8, 10)]
# ['#org__nalb_pfarre', 'Pfarrkirche in Neliv Nalib B.)', ['Pfarre', ' ', ' '], '#ev__QGW_II_I_1487', ' ', '1492', datetime.date(1401, 8, 10)]
# ['#org__wien', 'rats gemain der stat ze Wienn', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1497', 'other', '1497', datetime.date(1401, 11, 15)]
# ['#org__wien', 'städtischen Grundsiegel', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1497', 'witness', '1497', datetime.date(1401, 11, 15)]
# ['#org__st_stephan', 'sand Steffan ze Wienn', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1498', ' ', '1498', datetime.date(1401, 12, 14)]
# ['#org__st_niklas_vor_dem_stubentor', 'sand Niclas vor Stubentor ze Wienn', ['Kloster_f', 'OCist', 'St. Niklas-vor dem Stubentor'], '#ev__QGW_II_I_1500', ' ', '1500', datetime.date(1402, 1, 13)]
# ['#org__st_niklas_vor_dem_stubentor', 'convent gemain daselbigs', ['Kloster_f', 'OCist', 'St. Niklas-vor dem Stubentor'], '#ev__QGW_II_I_1500', 'issuer', '1500', datetime.date(1402, 1, 13)]
# ['#org__st_niklas_vor_dem_stubentor', 'Aussteller', ['Kloster_f', 'OCist', 'St. Niklas-vor dem Stubentor'], '#ev__QGW_II_I_1500', 'witness', '1500', datetime.date(1402, 1, 13)]
# ['#org__st_niklas_kapelle', 'kapellen, gehaissen dacz dem Alten sand Niclas in der Lantstrass zu Wienn', ['Kirche_Kapelle', ' ', ' '], '#ev__QGW_II_I_1501', ' ', '1501', datetime.date(1402, 1, 13)]
# ['#org__wien', 'dem Bürgermeister, Richter und Rathe der Stadt zu Wien', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1503', 'recipient', '1503', datetime.date(1402, 1, 20)]
# ['#org__buergerspital', 'selgere/at in der purger Spital vor Kernertor', ['Spital_Siechenhaus', ' ', 'Bürgerspital'], '#ev__QGW_II_I_1508', 'recipient', '1508', datetime.date(1402, 4, 25)]
# ['#org__buergerspital', 'ewigen Messe, welche Hermann, Hainreichs des statschreiber sun, den beiden got genad, in der egenanten purger Spital gestiftet hat', ['Spital_Siechenhaus', ' ', 'Bürgerspital'], '#ev__QGW_II_I_1508', 'recipient', '1508', datetime.date(1402, 4, 25)]
# ['#org__st_stephan', 'Chorherren und den curherren den echtem hinz sand Stephan ze Wienn', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1508', 'recipient', '1508', datetime.date(1402, 4, 25)]
# ['#org__minoriten', 'Minnernprüdern hinz der Neunstat', ['Kloster_m', 'OFMConv', 'Minoriten'], '#ev__QGW_II_I_1508', 'recipient', '1508', datetime.date(1402, 4, 25)]
# ['#org__st_stephan', 'hinz Allerheiligen tumkirchen dacz sand Stephan ze Wienn auf Allerheiligen altar', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1510', 'recipient', '1510', datetime.date(1402, 4, 27)]
# ['#org__wien', 'Rath der Stadt', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1510', 'other', '1510', datetime.date(1402, 4, 27)]
# ['#org__st_stephan', 'S. Stephan', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1510', ' ', '1510', datetime.date(1402, 4, 27)]
# ['#org__wien', 'städtischen Grundsiegel', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1510', 'witness', '1510', datetime.date(1402, 4, 27)]
# ['#org__wien', 'rat gemain der stat ze Wienn', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1513', 'issuer', '1513', datetime.date(1402, 7, 27)]
# ['#org__st_johanneskapelle_in_der_kaerntnerstrasse', 'hauses ze sand Johanns in der Chernerstrass', ['Kirche_Kapelle', ' ', 'St. Johanneskapelle-in der\n       Kärntnerstrasse'], '#ev__QGW_II_I_1513', ' ', '1513', datetime.date(1402, 7, 27)]
# ['#org__deutsche_herren', 'hauses dacz dem Teutschen haus ze Wienn', ['Kloster_m', 'OT', 'Deutsche Herren'], '#ev__QGW_II_I_1513', ' ', '1513', datetime.date(1402, 7, 27)]
# ['#org__wien', 'stat klainem anhangundem insigil', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1513', 'witness', '1513', datetime.date(1402, 7, 27)]
# ['#org__buergerspital', 'Spitalsiegel', ['Spital_Siechenhaus', ' ', 'Bürgerspital'], '#ev__QGW_II_I_1513', 'witness', '1513', datetime.date(1402, 7, 27)]
# ['#org__deutsche_herren', 'Deutschen Hauses', ['Kloster_m', 'OT', 'Deutsche Herren'], '#ev__QGW_II_I_1513', 'witness', '1513', datetime.date(1402, 7, 27)]
# ['#org__st_stephan', 'Unser Fraun altar, gelegen auf dem Lector dacz sand Stephan ze Wienn', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1515', 'recipient', '1515', datetime.date(1402, 8, 19)]
# ['#org__wien', 'Rathe der Stadt zu Wien', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1515', 'other', '1515', datetime.date(1402, 8, 19)]
# ['#org__st_stephan', 'Allerheiligen tumchirichen dacz sand Stephan ze Wienn', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1517', ' ', '1517', datetime.date(1402, 9, 7)]
# ['#org__st_achatiuskapelle', 'sand Achacii capellen, gelegen in dem pharrhof auf sand Stephans freithof daselbens', ['Kirche_Kapelle', ' ', 'Achatiuskapelle (St. Stephan)'], '#ev__QGW_II_I_1517', ' ', '1517', datetime.date(1402, 9, 7)]
# ['#org__wien', 'stat ze Wienn', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1517', ' ', '1517', datetime.date(1402, 9, 7)]
# ['#org__st_klara', 'sand Klarn ze Wienn', ['Kloster_f', 'OSCl', 'St. Klara'], '#ev__QGW_II_I_1520', ' ', '1520', datetime.date(1402, 12, 12)]
# ['#org__marienkapelle_am_gestade', 'Aindleftausent Maid altar, gelegen in Unser Fraun kappellen auf der Stetten ze Wienn', ['Kirche_Kapelle', ' ', 'Marienkapelle am Gestade, auf der\n       Stetten'], '#ev__QGW_II_I_1520', ' ', '1520', datetime.date(1402, 12, 12)]
# ['#org__wien', 'ze Wienn', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1520', ' ', '1520', datetime.date(1402, 12, 12)]
# ['#org__klosterneuburg_augustinerchorherren', 'klosters ze Neunburkch', ['Kloster_m', 'CanReg', 'Klosterneuburg-Augustinerchorherren'], '#ev__QGW_II_I_1521', ' ', '1521', datetime.date(1402, 12, 20)]
# ['#org__wien', 'rats gemain der stat ze Wienn', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1522', 'other', '1522', datetime.date(1402, 12, 20)]
# ['#org__st_michael', 'Goczleichnams altar, gelegen dacz sand Michel unter dem turn ze Wienn', ['Kirche_Kapelle', ' ', 'St. Michael'], '#ev__QGW_II_I_1522', ' ', '1522', datetime.date(1402, 12, 20)]
# ['#org__wien', 'städtischen Grundsiegel', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1522', 'witness', '1522', datetime.date(1402, 12, 20)]
# ['#org__karmeliter', 'ze Wienn Unser Fraun pru/eder ordens von dem perg Carmelo', ['Kloster_m', 'OCarm', 'Karmeliter-Weissenbrüder'], '#ev__QGW_II_I_1524', ' ', '1524', datetime.date(1403, 2, 5)]
# ['#org__karmeliter', 'convent', ['Kloster_m', 'OCarm', 'Karmeliter-Weissenbrüder'], '#ev__QGW_II_I_1524', 'issuer', '1524', datetime.date(1403, 2, 5)]
# ['#org__karmeliter', 'sand Johanns altar in dem ekke', ['Kloster_m', 'OCarm', 'Karmeliter-Weissenbrüder'], '#ev__QGW_II_I_1524', 'recipient', '1524', datetime.date(1403, 2, 5)]
# ['#org__karmeliter', 'Convent', ['Kloster_m', 'OCarm', 'Karmeliter-Weissenbrüder'], '#ev__QGW_II_I_1524', 'witness', '1524', datetime.date(1403, 2, 5)]
# ['#org__st_ulrich', 'Abhaltung dieses Jahrtages', ['Kirche_Kapelle', ' ', 'St. Ulrich Wien'], '#ev__QGW_II_I_1527', 'recipient', '1527', datetime.date(1403, 3, 1)]
# ['#org__st_stephan', 'Messe, welche ihre Mutter frau Margret die Chronvoglin dats sand Stephan ze Wienn auf sand Merten altar gestiftet hatte', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1531', 'recipient', '1531', datetime.date(1403, 3, 19)]
# ['#org__st_stephan', 'ihre Kapelle zu sand Stephan, die da geweihet ist in den eren des heiligen herren sand Moranden', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1533', 'recipient', '1533', datetime.date(1403, 3, 28)]
# ['#org__wien', 'städtischen Grundsiegel', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1533', ' ', '1533', datetime.date(1403, 3, 28)]
# ['#org__lassee_pfarre', 'Lauchsee', ['Pfarre', ' ', ' '], '#ev__QGW_II_I_1537', ' ', '1537', datetime.date(1403, 4, 30)]
# ['#org__st_stephan', 'ewigen Messe, die sie auf sand Merten altar dacz sand Stephan ze Wienn gestiftet hat,', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1539', 'recipient', '1539', datetime.date(1403, 5, 10)]
# ['#org__wien', 'rats gemain der stat ze Wienn', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1542_a', 'other', '1542', datetime.date(1403, 5, 29)]
# ['#org__st_michael', 'Gotesleichnamsaltar, gelegen dacz sand Michel under dem turn ze Wienn', ['Kirche_Kapelle', ' ', 'St. Michael'], '#ev__QGW_II_I_1542_a', ' ', '1542', datetime.date(1403, 5, 29)]
# ['#org__wien', 'Rathes', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1542_b', 'other', '1542', datetime.date(1403, 5, 29)]
# ['#org__st_michael', 'zu demselben Altare', ['Kirche_Kapelle', ' ', 'St. Michael'], '#ev__QGW_II_I_1542_b', 'recipient', '1542', datetime.date(1403, 5, 29)]
# ['#org__wien', 'städtischen Grundsiegel', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1542', ' ', '1542', datetime.date(1403, 5, 29)]
# ['#org__karmeliter', 'geistleichen herren closter Unser Fraun bruder, des ordens von dem perg Carmelo, gelegen an der Herzogen hof ze Wienn', ['Kloster_m', 'OCarm', 'Karmeliter-Weissenbrüder'], '#ev__QGW_II_I_1545', ' ', '1545', datetime.date(1403, 6, 28)]
# ['#org__karmeliter', 'Convent', ['Kloster_m', 'OCarm', 'Karmeliter-Weissenbrüder'], '#ev__QGW_II_I_1545', 'issuer', '1545', datetime.date(1403, 6, 28)]
# ['org__wien', 'rates gemain der stat ze Wienn', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1550', 'other', '1550', datetime.date(1403, 8, 16)]
# ['#org__wien', 'städtischen Grundsiegel', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1550', 'witness', '1550', datetime.date(1403, 8, 16)]
# ['#org__st_stephan', 'seiner herren von Tierna stift und chapellen, die da geweichet ist in den eren des heiligen herren sand Morand', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1552', 'recipient', '1552', datetime.date(1403, 8, 21)]
# ['#org__wien', 'rat gemain der stat ze Wienn', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1555', 'issuer', '1555', datetime.date(1403, 9, 7)]
# ['#org__raab_dominikaner', 'geistleichen herren chloster dacz den Predigern ze Rab', ['Kloster_m', 'OP', 'Raab Prediger'], '#ev__QGW_II_I_1555', ' ', '1555', datetime.date(1403, 9, 7)]
# ['#org__wien', 'stat ze Wienn klainem anhangundem insigil', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1555', 'witness', '1555', datetime.date(1403, 9, 7)]
# ['#org__rein_zisterzienser', 'convent dacz Re/aun, des ordens von Czitel, in Salzpurger bistum', ['Kloster_m', 'OCist', 'Rein-Zisterzienser'], '#ev__QGW_II_I_1558', 'recipient', '1558', datetime.date(1403, 9, 29)]
# ['#org__st_laurenz_am_alten_fleischmarkt', 'geistleichen fraun dacz sand Laurenzen am Alten Fleischmarcht', ['Kloster_f', 'OP', 'St. Laurenz-am alten Fleischmarkt'], '#ev__QGW_II_I_1560', 'recipient', '1560', datetime.date(1403, 10, 5)]
# ['#org__st_niklas_vor_dem_stubentor', 'sand Niclas vor Stubentor', ['Kloster_f', 'OCist', 'St. Niklas-vor dem Stubentor'], '#ev__QGW_II_I_1560', 'recipient', '1560', datetime.date(1403, 10, 5)]
# ['#org__st_jakob_auf_der_huelben', 'sand Jacob', ['Kloster_f', 'CanReg', 'St. Jakob-auf der Hülben'], '#ev__QGW_II_I_1560', 'recipient', '1560', datetime.date(1403, 10, 5)]
# ['#org__st_agnes_auf_der_himmelpforte', 'der Himelporten', ['Kirche_Kapelle', ' ', 'St. Agnes-auf der Himmelpforte'], '#ev__QGW_II_I_1560', 'recipient', '1560', datetime.date(1403, 10, 5)]
# ['#org__st_maria_magdalena_vor_dem_schottentor', 'sand Margamagdalen vor Schottentor', ['Kloster_f', 'OSMM', 'St. Maria Magdalena-vor dem\n       Schottentor'], '#ev__QGW_II_I_1560', 'recipient', '1560', datetime.date(1403, 10, 5)]
# ['#org__st_lazarus_siechenhaus', 'sand Laser vor Stubentor', ['Spital_Siechenhaus', ' ', 'St. Lazarus-Siechenhaus (St.\n       Marx)'], '#ev__QGW_II_I_1560', 'recipient', '1560', datetime.date(1403, 10, 5)]
# ['#org__st_hiob_zum_klagbaum', 'dem Klagpaum', ['Kirche_Kapelle', ' ', 'St. Hiob-zum Klagbaum'], '#ev__QGW_II_I_1560', 'recipient', '1560', datetime.date(1403, 10, 5)]
# ['#org__st_johannes_in_der_siechenals', 'sand Johans in der Siechen Allse', ['Kirche_Kapelle', ' ', 'St. Johannes in der Siechenals'], '#ev__QGW_II_I_1560', 'recipient', '1560', datetime.date(1403, 10, 5)]
# ['#org__heiligengeistspital', 'Heiligengeist vor Chernertor', ['Spital_Siechenhaus', ' ', 'Heiligengeistspital'], '#ev__QGW_II_I_1560', 'recipient', '1560', datetime.date(1403, 10, 5)]
# ['#org__st_hieronymus', 'sand Jeronimus', ['Kloster_f', 'OSMM', ' '], '#ev__QGW_II_I_1560', 'recipient', '1560', datetime.date(1403, 10, 5)]
# ['#org__dominikaner', 'den Predigern', ['Kloster_m', 'OP', 'Dominikaner'], '#ev__QGW_II_I_1560', 'recipient', '1560', datetime.date(1403, 10, 5)]
# ['#org__augustinereremiten', 'den Augustinern', ['Kloster_m', 'OESA', 'Augustinereremiten'], '#ev__QGW_II_I_1560', 'recipient', '1560', datetime.date(1403, 10, 5)]
# ['#org__minoriten', 'den Minornprüdern', ['Kloster_m', 'OFMConv', 'Minoriten'], '#ev__QGW_II_I_1560', 'recipient', '1560', datetime.date(1403, 10, 5)]
# ['#org__buergerspital', 'purger Spital vor Chernertor ze Wienn', ['Spital_Siechenhaus', ' ', 'Bürgerspital'], '#ev__QGW_II_I_1560', 'recipient', '1560', datetime.date(1403, 10, 5)]
# ['#org__st_stephan', 'sand Stephan', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1560', 'recipient', '1560', datetime.date(1403, 10, 5)]
# ['#org__st_laurenz_am_alten_fleischmarkt', 'sand Laurenzen am Alten Fleischmarkcht', ['Kloster_f', 'OP', 'St. Laurenz-am alten Fleischmarkt'], '#ev__QGW_II_I_1560', 'recipient', '1560', datetime.date(1403, 10, 5)]
# ['#org__st_stephan', 'chorherrn dacz sand Stephan ze Wienn', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1560', 'recipient', '1560', datetime.date(1403, 10, 5)]
# ['#org__st_stephan', 'S. Stephan', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1560', 'recipient', '1560', datetime.date(1403, 10, 5)]
# ['#org__wien', 'rats gemain der stat ze Wienn', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1562', 'other', '1562', datetime.date(1403, 10, 12)]
# ['#org__wien', 'städtischen Grundsiegel', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1562', 'witness', '1562', datetime.date(1403, 10, 12)]
# ['#org__st_hieronymus_kapelle', 'sand Jeronimi chapellen zu Wienn auf Gotesleichnams altar zu einer ewigen Messe', ['Kirche_Kapelle', ' ', ' '], '#ev__QGW_II_I_1563', 'recipient', '1563', datetime.date(1403, 11, 10)]
# ['#org__st_stephan', 'ihre Kapelle dacz sand Stephan ze Wienn, die geweicht ist in den ern sand Morand', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1565', 'recipient', '1565', datetime.date(1403, 11, 27)]
# ['#org__moedling_pfarre', 'pharrkirichen ze Medling', ['Pfarre', ' ', ' '], '#ev__QGW_II_I_1566', ' ', '1566', datetime.date(1403, 12, 29)]
# ['#org__schreiberzeche_auf_dem_neuen_karner', 'pruederschaft auf dem neun Charner dacz sand Stephan ze Wienn', ['Zeche_Bruderschaft', ' ', 'Schreiberzeche auf dem Neuen Karner'], '#ev__QGW_II_I_1566', ' ', '1566', datetime.date(1403, 12, 29)]
# ['#org__schreiberzeche_auf_dem_neuen_karner', 'dieser Bruderschaft', ['Zeche_Bruderschaft', ' ', 'Schreiberzeche auf dem Neuen Karner'], '#ev__QGW_II_I_1566', 'recipient', '1566', datetime.date(1403, 12, 29)]
# ['#org__herzog', 'herzoglichen Bergsiegel', ['Hof', ' ', 'herzoglich etc'], '#ev__QGW_II_I_1566', 'witness', '1566', datetime.date(1403, 12, 29)]
# ['#org__klosterneuburg_augustinerchorherren', 'klosters ze Neunburkch', ['Kloster_m', 'CanReg', 'Klosterneuburg-Augustinerchorherren'], '#ev__QGW_II_I_1567', ' ', '1567', datetime.date(1404, 1, 5)]
# ['#org__st_stephan', 'chaplanei, die Jo/erg der Nustorffer, dem got gnad geschafft hat hinz sand Stephan ze Wienn, zu dieser Kaplanei', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1567', ' ', '1567', datetime.date(1404, 1, 5)]
# ['#org__st_stephan', 'sand Morando chapellen, gelegen dacz sand Stephann ze Wienn', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1569', 'recipient', '1569', datetime.date(1404, 1, 17)]
# ['#org__wien', 'rats gemain der stat ze Wienn', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1579', 'other', '1579', datetime.date(1404, 4, 19)]
# ['#org__st_stephan', 'curherren dacz Allerheiligen tumkirchen dacz sand Stephan ze Wienn zu einem ewigen Jahrtage', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1579', 'recipient', '1579', datetime.date(1404, 4, 19)]
# ['#org__wien', 'städtischen Grundsiegel', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1579', 'witness', '1579', datetime.date(1404, 4, 19)]
# ['#org__st_hieronymus', 'haus dacz sand Jeronimus, gelegen in der Su/enigerstrass', ['Kloster_f', 'OSMM', ' '], '#ev__QGW_II_I_1581', 'recipient', '1581', datetime.date(1404, 4, 22)]
# ['#pe__albrecht_stekch', 'Grundherrn', [' ', ' ', ' '], '#ev__QGW_II_I_1581', 'witness', '1581', datetime.date(1404, 4, 22)]
# ['#org__deutsche_herren', 'Deutschen Hauses', ['Kloster_m', 'OT', 'Deutsche Herren'], '#ev__QGW_II_I_1587', 'witness', '1587', datetime.date(1404, 6, 9)]
# ['#org__wien', 'rats gemain der stat ze Wienn', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1592', 'other', '1592', datetime.date(1404, 9, 4)]
# ['#org__wien', 'städtischen Grundsiegel', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1592', 'witness', '1592', datetime.date(1404, 9, 4)]
# ['#org__wien', 'rats gemain der stat ze Wienn', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1597', 'other', '1597', datetime.date(1404, 10, 25)]
# ['#org__wien', 'städtischen Grundsiegel', ['Stadt', ' ', 'Bürgermeister Rat und Bürger'], '#ev__QGW_II_I_1597', 'witness', '1597', datetime.date(1404, 10, 25)]
# ['#org__st_stephan', 'sand Dorethen altar daselbs der ewigen messe, die in der Schu/eler zeche gehöret', ['Kirche_Kapelle', ' ', 'St. Stephan'], '#ev__QGW_II_I_1607_a', ' ', '1607', datetime.date(1404, 12, 13)]
# ['#org__st_paul_erdberg', 'sand Paul ze Erdpurkch bei Wienn', ['Pfarre', ' ', 'Erdberg - St. Paul'], '#ev__QGW_II_I_1608', ' ', '1608', datetime.date(1404, 12, 15)]
# ['#org__st_paul_erdberg', 'Kirche von S. Paul', ['Pfarre', ' ', 'Erdberg - St. Paul'], '#ev__QGW_II_I_1608', 'witness', '1608', datetime.date(1404, 12, 15)]
